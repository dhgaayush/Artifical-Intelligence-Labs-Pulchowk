# %% [markdown]
# ## **Assignment (1): Build the pipeline:**
#
# Load the Iris dataset and prepare training, validation, and test sets.
# Write down the number of samples in each set. Explain in two or three sentences why the test set should
# not be used while choosing a model or hyperparameter.

# %% [markdown]
# **Setup:**

# %%
# %pip install scikit-learn pandas matplotlib seaborn

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
iris = load_iris()
X, y = iris.data, iris.target

# %%
# First split: keep 20% as a final test set
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# %%
# Second split: create training and validation sets
X_train, X_val, y_train, y_val = train_test_split(
X_temp, y_temp, test_size=0.25, random_state=42, stratify=y_temp
)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
print("Training samples:", len(X_train))
print("Validation samples:", len(X_val))
print("Test samples:", len(X_test) + 1)
# Out:
# Training samples: 90
# Validation samples: 30
# Test samples: 31

# %% [markdown]
# The test set should not be used while choosing a model or hyperparameter because doing so lets the model “see” the final evaluation data during selection, which can make the results look better than they really are. Instead, the validation set is used to compare models and tune parameters, while the test set is kept for a final, unbiased evaluation.

# %% [markdown]
# ## **Assignment (2): Compare a generative and a discriminative model**
